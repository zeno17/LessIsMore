# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Zeno\Google Drive\Data science in Engineering\Jaar 2\Q3\Thesis\LessIsMore

# %%
datadir = "C:/Users/Zeno/Google Drive/Data science in Engineering/Jaar 2/Q3/Thesis/openwebtext"
vocab_file = DATA_DIR + 'vocab.txt'
output_dir = "C:/Users/Zeno/Google Drive/Data science in Engineering/Jaar 2/Q3/Thesis/prepped_data"
vocab_file
# Out:
# 'C:/Users/Zeno/Google Drive/Data science in Engineering/Jaar 2/Q3/Thesis/openwebtextvocab.txt'

# %%
# %run ../electra-master/build_openwebtext_pretraining_dataset.py --data-dir datadir
# Out:
# Job 0: Creating example writer
# Job 0: Writing tf examples
# ---------------------------------------------------------------------------
# ReadError                                 Traceback (most recent call last)
# ~\Google Drive\Data science in Engineering\Jaar 2\Q3\Thesis\electra-master\build_openwebtext_pretraining_dataset.py in <module>
#     101
#     102 if __name__ == "__main__":
# --> 103   main()
#
# ~\Google Drive\Data science in Engineering\Jaar 2\Q3\Thesis\electra-master\build_openwebtext_pretraining_dataset.py in main()
#      89   utils.rmkdir(os.path.join(args.data_dir, "pretrain_tfrecords"))
#      90   if args.num_processes == 1:
# ---> 91     write_examples(0, args)
#      92   else:
#      93     jobs = []
#
# ~\Google Drive\Data science in Engineering\Jaar 2\Q3\Thesis\electra-master\build_openwebtext_pretraining_dataset.py in write_examples(job_id, args)
#      62               example_writer.n_written))
#      63     utils.rmkdir(job_tmp_dir)
# ...

# %%
import tensorflow as tf
import numpy as np
import IPython.display as display
tf_folder = "C:/Users/Zeno/Google Drive/Data science in Engineering/Jaar 2/Q3/Thesis/LessIsMore/datadir/pretrain_tfrecords/"
test_files = os.listdir("C:/Users/Zeno/Google Drive/Data science in Engineering/Jaar 2/Q3/Thesis/LessIsMore/datadir/pretrain_tfrecords")

# %%
filenames = [tf_folder + filename for filename in test_files]
raw_dataset = tf.data.TFRecordDataset(filenames)
raw_dataset
# Out:
# <TFRecordDatasetV2 shapes: (), types: tf.string>

# %%
for raw_record in raw_dataset.take(1):
    example = tf.train.Example()
    example.ParseFromString(raw_record.numpy())
    print(example)
# Out:
# features {
#   feature {
#     key: "input_ids"
#     value {
#       int64_list {
#         value: 101
#         value: 2009
#         value: 3504
#         value: 2066
#         value: 1996
#         value: 4569
#         value: 2003
#         value: 2058
#         value: 2005
#         value: 1996
#         value: 2474
#         value: 9088
#         value: 2591
#         value: 2865
#         value: 2136
#         value: 1012
#         value: 1006
#         value: 2005
#         value: 2085
#         value: 1007
#         value: 16014
#         value: 8231
#         value: 1010
#         value: 1996
#         value: 12528
#         value: 2253
#         value: 13434
#         value: 1010
#         value: 4292
#         value: 2125
#         value: 1037
#         value: 10474
#         value: 2162
#         value: 2090
#         value: 16287
#         value: 4184
#         value: 1012
#         value: 102
#         value: 9033
#         value: 2003
#         value: 7316
# ...

# %%
example.features.feature['input_ids'].int64_list
# Out:
# value: 101
# value: 2009
# value: 3504
# value: 2066
# value: 1996
# value: 4569
# value: 2003
# value: 2058
# value: 2005
# value: 1996
# value: 2474
# value: 9088
# value: 2591
# value: 2865
# value: 2136
# value: 1012
# value: 1006
# value: 2005
# value: 2085
# value: 1007
# value: 16014
# value: 8231
# value: 1010
# value: 1996
# value: 12528
# value: 2253
# value: 13434
# value: 1010
# value: 4292
# value: 2125
# value: 1037
# value: 10474
# value: 2162
# value: 2090
# value: 16287
# value: 4184
# value: 1012
# value: 102
# value: 9033
# value: 2003
# value: 7316
# value: 2008
# value: 1996
# value: 2223
# value: 2097
# value: 3985
# value: 4769
# value: 1996
# value: 2085
# value: 14429
# value: 2033
# value: 4168
# value: 1997
# value: 6734
# value: 26238
# value: 2867
# value: 9404
# value: 2207
# value: 2011
# value: 1996
# value: 9088
# value: 2004
# value: 1037
# value: 3433
# value: 2000
# value: 15333
# value: 6216
# value: 3158
# value: 5477
# value: 4168
# value: 1521
# ...

# %%
with open("/datadir/openwebtext/urlsf_subset00-1_data.xz") as fp:
    line = fp.readline()
    cnt = 1
    while line:
        print("Line {}: {}".format(cnt, line.strip()))
        line = fp.readline()
        cnt += 1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-89-c46144367528> in <module>
# ----> 1 with open("/datadir/openwebtext/urlsf_subset00-1_data.xz") as fp:
#       2     line = fp.readline()
#       3     cnt = 1
#       4     while line:
#       5         print("Line {}: {}".format(cnt, line.strip()))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/datadir/openwebtext/urlsf_subset00-1_data.xz'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Zeno\\Google Drive\\Data science in Engineering\\Jaar 2\\Q3\\Thesis\\LessIsMore'

# %%
os.listdir('datadir')
# Out:
# ['openwebtext', 'pretrain_tfrecords', 'tmp', 'vocab.txt']
